# %% [markdown]
# ---
# title: JQUERY Hacks
# toc: true
# description: html table
# courses: { csa: {week: 3} }
# type: tangibles
# ---

# %%
# %%html
# <h2>Soccer Teams</h2>
#
# <style>
#     /* Style the table */
#     table {
#         width: 100%;
#         border-collapse: collapse;
#     }
#
#     /* Style table headers */
#     th {
#         background-color: #blue;
#         color: pink;
#         font-weight: bold;
#         padding: 10px;
#     }
#
#     /* Style alternate rows with different background colors */
#     tr:nth-child(odd) {
#         background-color: #d497f1;
#     }
#
#     tr:nth-child(even) {
#         background-color: #04d9ff;
#     }
#
#     /* Style table cells */
#     td {
#         padding: 8px;
#         text-align: center;
#     }
#
#     /* Add hover effect to table rows */
#     tr:hover {
#         background-color: #ddd;
#     }
# </style>
#
# <body>
#     <table class="table">
#         <thead>
#             <tr>
#                 <th>Team</th>
#                 <th>Country</th>
#                 <th>Founded</th>
#                 <th>Stadium</th>
#                 <th>Trophies</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>Real Madrid</td>
#                 <td>Spain</td>
#                 <td>1902</td>
#                 <td>Santiago Bernabeu</td>
#                 <td>34 La Liga, 13 UEFA Champions League</td>
#             </tr>
#             <tr>
#                 <td>FC Barcelona</td>
#                 <td>Spain</td>
#                 <td>1899</td>
#                 <td>Camp Nou</td>
#                 <td>26 La Liga, 5 UEFA Champions League</td>
#             </tr>
#             <tr>
#                 <td>Manchester United</td>
#                 <td>England</td>
#                 <td>1878</td>
#                 <td>Old Trafford</td>
#                 <td>20 Premier League, 3 UEFA Champions League</td>
#             </tr>
#             <tr>
#                 <td>Bayern Munich</td>
#                 <td>Germany</td>
#                 <td>1900</td>
#                 <td>Allianz Arena</td>
#                 <td>31 Bundesliga, 6 UEFA Champions League</td>
#             </tr>
#             <tr>
#                 <td>Juventus</td>
#                 <td>Italy</td>
#                 <td>1897</td>
#                 <td>Allianz Stadium</td>
#                 <td>36 Serie A, 2 UEFA Champions League</td>
#             </tr>
#         </tbody>
#     </table>
# </body>
# Out:
# <h2>Soccer Teams</h2>
#
# <style>
#     /* Style the table */
#     table {
#         width: 100%;
#         border-collapse: collapse;
#     }
#
#     /* Style table headers */
#     th {
#         background-color: #blue;
#         color: pink;
#         font-weight: bold;
#         padding: 10px;
#     }
#
#     /* Style alternate rows with different background colors */
#     tr:nth-child(odd) {
#         background-color: #d497f1;
#     }
#
#     tr:nth-child(even) {
#         background-color: #04d9ff;
#     }
#
#     /* Style table cells */
#     td {
#         padding: 8px;
#         text-align: center;
#     }
#
#     /* Add hover effect to table rows */
#     tr:hover {
#         background-color: #ddd;
#     }
# </style>
#
# <body>
#     <table class="table">
#         <thead>
#             <tr>
#                 <th>Team</th>
#                 <th>Country</th>
#                 <th>Founded</th>
#                 <th>Stadium</th>
#                 <th>Trophies</th>
# ...

# %% [markdown]
# # Questions and Answers.
#
# - A benifit of a markdown table is its easily able to be used within a blog, and its has easy readability. However the most important factor of a markdown table is its very organized and can be manipulated with js css, and html.
#
# - Html vs JS, html is a static language meaning that it sets headers and is text based which means you can write, but most importantly it sets up div which can be used with css to customize and have function through js. On the other hand JS is a language with functins and if and else satements that can be used based on html and css creating a frontend scheme.
#
# -  A benfift that js talbes has it allows for a real time updates with ability to update with api features such as post put get.
